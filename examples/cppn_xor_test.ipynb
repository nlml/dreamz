# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from dreamz.cppn import get_cppn_im_gen_fn_and_opt
from dreamz.render import test_xor
size = 32
device = 'cuda'
im_gen_fn, opt = get_cppn_im_gen_fn_and_opt(size, device)
test_xor(im_gen_fn, device, opt)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# cost 0.31840723752975464
#   1%|          | 1/100 [00:00<00:14,  6.84it/s]
# cost 0.06309391558170319
#  11%|█         | 11/100 [00:00<00:09,  9.34it/s]
# cost 0.024671949446201324
#  21%|██        | 21/100 [00:00<00:06, 12.55it/s]
# cost 0.015206774696707726
#  31%|███       | 31/100 [00:00<00:04, 16.56it/s]
# cost 0.0099403727799654
#  41%|████      | 41/100 [00:00<00:02, 21.34it/s]
# cost 0.007612545043230057
#  51%|█████     | 51/100 [00:00<00:01, 26.79it/s]
# cost 0.006002403795719147
#  61%|██████    | 61/100 [00:01<00:01, 31.76it/s]
# cost 0.004960335791110992
#  71%|███████   | 71/100 [00:01<00:00, 37.74it/s]
# cost 0.004227732308208942
#  81%|████████  | 81/100 [00:01<00:00, 43.47it/s]
# cost 0.003659662790596485
# 100%|██████████| 100/100 [00:01<00:00, 63.75it/s]
